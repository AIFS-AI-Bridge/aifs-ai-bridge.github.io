# %% [markdown]
# # **LAB 3**
# ## Goal: test different models with the wine dataset
#
# Make sure you uploaded the data into the Colab! The dataset is at https://archive.ics.uci.edu/dataset/109/wine (just click on winequality-red.csv and winequality-white.csv).
#
# Remember, you can always google things that you don't know. For example, you can google "python print function" if you dont know what print() does. Also, feel free to add whatever lines you need and print out data whenever you want.

# %%
# download wine quality dataset directly
# !wget https://archive.ics.uci.edu/static/public/186/wine+quality.zip

# %%
# unzip the wine quality dataset
# !unzip wine+quality.zip

# %%
# *————— Standard reading procedure for wine quality dataset —————*
#         ^ check lab 2 if you would like to refresh your memory

opened_red_data = open('/content/winequality-red.csv','r')
opened_white_data = open('/content/winequality-white.csv','r')

red_data_lines = opened_red_data.readlines()
opened_red_data.close()
red_data_lines.pop(0)

white_data_lines = opened_white_data.readlines()
opened_white_data.close()
white_data_lines.pop(0)
# *————————————————————————————————————————————————————————————————*


print("Example of a line from red data:")
red_data_lines[0]

# %% [markdown]
# ### Clean your data first!
# As we did with the wine dataset in previous labs, make sure you clean the data and put it into a 2D list so that we can manipulate it later on.

# %% [markdown]
# ### Shuffle your data!
# Do so with the `random` library.

# %%
# Reminders: (indexes for each line)
# 0 = fixed acidity, 1 = volatile acidity, 2 = citric acid, 3 = residual sugar,
# 4 = chlorides, 5 = free sulfur dioxide, 6 = total sulfur dioxide,
# 7 = density, 8 = pH, 9 = sulphates, 10 = alcohol, 11 = quality, 12 = type

# %% [markdown]
# ### Logistic Regression
# Write a logistic regression classifier below.
# ___
# **THINGS TO THINK ABOUT**
# * what feature do we want to use as the output?
# * how many datasets do we want to save for testing?
# * how can we use scikit-learn's toolkit to leverage prebuilt resources?
# * how can we evaluate our model?

# %% [markdown]
# ## Linear Regression
# Write a linear regression model below.
# ___
# **THINGS TO THINK ABOUT**
# * what feature do we want to use as the output?
# * how many datasets do we want to save for testing?
# * how can we use scikit-learn's toolkit to leverage prebuilt resources?
# * how can we evaluate our model?

# %% [markdown]
# ### BONUS: Polynomial Regression
# Extend your use of the linear regression class to use some polynomial terms like we did in the demo!
